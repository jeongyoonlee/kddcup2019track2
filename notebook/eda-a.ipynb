# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from glob import glob
import json
from matplotlib import pyplot as plt
import numpy as np
import os
import pandas as pd
from pprint import pprint
import seaborn as sns

# %%
plt.style.use('fivethirtyeight')
pd.set_option('max_columns', 100)

# %%
data_dir = '../data/data_public/A'
build_dir = '../build/'
model_dir = os.path.join(build_dir, 'model')
metric_dir = os.path.join(build_dir, 'metric')
val_dir = os.path.join(build_dir, 'val')
tst_dir = os.path.join(build_dir, 'tst')
sub_dir = os.path.join(build_dir, 'sub')

info_file = os.path.join(data_dir, 'train', 'info.json')
train_feature_file = os.path.join(data_dir, 'train', 'main_train.data')
train_label_file = os.path.join(data_dir, 'train', 'main_train.solution')
test_feature_file = os.path.join(data_dir, 'test', 'main_test.data')
table_files = glob(os.path.join(data_dir, 'train', 'table_*.data'))

# %%
table_files
# Out:
# ['../data/data_public/A/train/table_1.data',
#  '../data/data_public/A/train/table_3.data',
#  '../data/data_public/A/train/table_2.data']

# %%
with open(info_file, 'r') as f:
    info = json.load(f)
    
pprint(info)
# Out:
# {'relations': [{'key': ['c_01'],
#                 'table_A': 'main',
#                 'table_B': 'table_1',
#                 'type': 'many_to_many'},
#                {'key': ['c_02'],
#                 'table_A': 'main',
#                 'table_B': 'table_2',
#                 'type': 'many_to_one'},
#                {'key': ['c_02'],
#                 'table_A': 'main',
#                 'table_B': 'table_3',
#                 'type': 'many_to_one'}],
#  'start_time': 1550654179,
#  'tables': {'main': {'c_01': 'cat',
#                      'c_02': 'cat',
#                      'c_1': 'cat',
#                      'c_10': 'cat',
#                      'c_11': 'cat',
#                      'c_12': 'cat',
#                      'c_13': 'cat',
#                      'c_14': 'cat',
#                      'c_15': 'cat',
#                      'c_16': 'cat',
#                      'c_17': 'cat',
#                      'c_2': 'cat',
#                      'c_3': 'cat',
#                      'c_4': 'cat',
#                      'c_5': 'cat',
#                      'c_6': 'cat',
#                      'c_7': 'cat',
#                      'c_8': 'cat',
#                      'c_9': 'cat',
#                      'n_1': 'num',
#                      'n_10': 'num',
#                      'n_11': 'num',
#                      'n_12': 'num',
#                      'n_13': 'num',
#                      'n_14': 'num',
#                      'n_15': 'num',
#                      'n_16': 'num',
#                      'n_17': 'num',
#                      'n_2': 'num',
#                      'n_3': 'num',
#                      'n_4': 'num',
#                      'n_5': 'num',
#                      'n_6': 'num',
#                      'n_7': 'num',
#                      'n_8': 'num',
#                      'n_9': 'num',
#                      't_01': 'time'},
#             'table_1': {'c_01': 'cat',
#                         'c_1': 'cat',
#                         'c_2': 'cat',
#                         'c_3': 'cat',
#                         'c_4': 'cat',
#                         'm_1': 'multi-cat',
#                         'm_2': 'multi-cat',
#                         't_01': 'time'},
#             'table_2': {'c_02': 'cat',
#                         'c_1': 'cat',
#                         'c_10': 'cat',
#                         'c_11': 'cat',
#                         'c_12': 'cat',
#                         'c_2': 'cat',
#                         'c_3': 'cat',
#                         'c_4': 'cat',
#                         'c_5': 'cat',
#                         'c_6': 'cat',
#                         'c_7': 'cat',
#                         'c_8': 'cat',
#                         'c_9': 'cat',
#                         'm_1': 'multi-cat',
#                         'm_2': 'multi-cat',
#                         'm_3': 'multi-cat',
#                         'm_4': 'multi-cat',
#                         'n_1': 'num',
#                         'n_2': 'num'},
#             'table_3': {'c_02': 'cat',
#                         'n_1': 'num',
#                         'n_2': 'num',
#                         'n_3': 'num',
#                         'n_4': 'num'}},
#  'time_budget': 600,
#  'time_col': 't_01'}

# %%
trn_feature = pd.read_csv(train_feature_file, sep='\t', parse_dates=['t_01'],
                          date_parser=lambda x: pd.to_datetime(x, unit='ms'))
print(trn_feature.shape)
trn_feature.head()
# Out:
# /Users/jeong/.conda/envs/jeong/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (17,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (808953, 37)
#                     c_1                    t_01                  c_2      n_1  \
# 0   6424309506653688772 2017-05-12 03:11:10.767  5970293430443902067  32.0619
# 1   8532826394476824675 2017-05-12 03:11:10.763  5970293430443902067  12.5251
# 2   8238904032236558884 2017-05-12 03:11:10.558  5970293430443902067  16.1738
# 3   5905740630224410631 2017-05-12 03:11:10.547  5970293430443902067  23.0458
# 4  14597100768854648050 2017-05-12 03:11:10.648  5970293430443902067  18.5793
#
#                    c_3  n_2  n_3  n_4  n_5      n_6      n_7     n_8  n_9  \
# 0    71566636588341348  1.0  4.0    1  1.0  21764.5  12265.0  1550.5  7.0
# 1  1342601528526025535  1.0  1.0    1  1.0   1229.5    677.5    59.5  1.0
# 2  1342601528526025535  1.0  1.0    1  2.5   2194.0   1340.5   136.0  2.5
# 3  1342601528526025535  1.0  2.5    1  1.0   6661.0   3412.0   370.0  1.0
# 4  1342601528526025535  1.0  1.0    1  1.0   2861.5   1517.5   139.0  1.0
#
#    n_10  n_11  c_4                   c_5                  c_6  c_7  \
# 0   1.0   1.0  NaN  11831082022210354946  2240218224734853194  NaN
# 1   1.0   1.0  NaN  11831082022210354946  2240218224734853194  NaN
# 2   1.0   1.0  NaN  11831082022210354946  2240218224734853194  NaN
# 3   1.0   1.0  NaN  11831082022210354946  2240218224734853194  NaN
# 4   1.0   1.0  NaN  11831082022210354946  2240218224734853194  NaN
#
#             c_8                  c_9                  c_10  \
# 0  5.563825e+18  6052790789500362338  15800027118942146668
# 1  5.563825e+18  6052790789500362338  15800027118942146668
# 2  5.563825e+18  6052790789500362338  15800027118942146668
# 3  5.563825e+18  6052790789500362338  15800027118942146668
# 4  5.563825e+18  6052790789500362338  15800027118942146668
#
#                   c_11                  c_12                 c_13  \
# 0  6453607437363194232  11761078935003679703  6843963171864976598
# 1  6453607437363194232  11761078935003679703  6843963171864976598
# 2  6453607437363194232  11761078935003679703  6843963171864976598
# 3  6453607437363194232  11761078935003679703  6843963171864976598
# 4  6453607437363194232  11761078935003679703  6843963171864976598
#
#                  c_14  n_12  n_13  n_14  n_15  n_16                  c_15  \
# 0  828243681803128523   1.0   1.0   1.0     1   1.0  16046562646186466166
# 1  828243681803128523   1.0   1.0   1.0     1   1.0  16046562646186466166
# 2  828243681803128523   1.0   1.0   1.0     1   1.0  16046562646186466166
# 3  828243681803128523   1.0   1.0   1.0     1   1.0  16046562646186466166
# 4  828243681803128523   1.0   1.0   1.0     1   1.0  16046562646186466166
#
#                    c_16     n_17                  c_17                  c_02  \
# 0  11877483212745539743  1.14404  17280693952210522585  10120010452384736852
# 1  11877483212745539743  1.14085  14919582067413543358  10399812292535181927
# 2  11877483212745539743  1.14055   9712055990861830264  16981951333260823653
# 3  11877483212745539743  1.13880  12472614627876446882  11155935198576391041
# 4  11877483212745539743  1.13725   3546733086056819470   8093248447354845242
#
#                   c_01
# 0  9367096725129711792
# 1  9367096725129711792
# 2  9367096725129711792
# 3  9367096725129711792
# 4  9367096725129711792

# %%
trn_feature.t_01.min(), trn_feature.t_01.max()
# Out:
# (Timestamp('2017-05-12 03:00:00.500000'),
#  Timestamp('2017-05-12 03:59:59.800000'))

# %%
tst_feature = pd.read_csv(test_feature_file, sep='\t', parse_dates=['t_01'],
                          date_parser=lambda x: pd.to_datetime(x, unit='ms'))
print(tst_feature.shape)
tst_feature.head()
# Out:
# /Users/jeong/.conda/envs/jeong/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns